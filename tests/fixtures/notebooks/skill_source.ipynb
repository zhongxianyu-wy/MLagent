# %% [markdown]
# # XGBoost methylation baseline
# Use standardization, low variance filtering, and XGBoost with Youden threshold.

# %%
preprocessing = 'standardize'
feature_subset = 'low_variance'
model = 'xgboost'
